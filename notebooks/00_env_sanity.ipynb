# %% [markdown]
# ## Environment Setup

# %%
pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /Users/adriankazi/Desktop/world_models_dreamer/.venv/lib/python3.11/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/adriankazi/Desktop/world_models_dreamer/.venv/lib/python3.11/site-packages (from gymnasium) (2.4.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/adriankazi/Desktop/world_models_dreamer/.venv/lib/python3.11/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/adriankazi/Desktop/world_models_dreamer/.venv/lib/python3.11/site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/adriankazi/Desktop/world_models_dreamer/.venv/lib/python3.11/site-packages (from gymnasium) (0.0.4)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.envs.make_env import make_env

# %% [markdown]
# ### Rollout

# %%
env = make_env()
obs, inf = env.reset()

for t in range(20):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    print(t, obs, reward)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# 0 [ 0.03215253 -0.15399769  0.01112257  0.3189779 ] 1.0
# 1 [ 0.02907258 -0.34927627  0.01750213  0.6151476 ] 1.0
# 2 [ 0.02208706 -0.54463834  0.02980508  0.9132912 ] 1.0
# 3 [ 0.01119429 -0.7401505   0.0480709   1.2151906 ] 1.0
# 4 [-0.00360872 -0.5456805   0.07237472  0.93795   ] 1.0
# 5 [-0.01452233 -0.74169976  0.09113372  1.2524687 ] 1.0
# 6 [-0.02935633 -0.93786335  0.11618309  1.5722493 ] 1.0
# 7 [-0.04811359 -0.7443034   0.14762808  1.3179477 ] 1.0
# 8 [-0.06299967 -0.5513243   0.17398703  1.0748729 ] 1.0
# 9 [-0.07402615 -0.35887438  0.19548449  0.8414508 ] 1.0
# 10 [-0.08120363 -0.5560505   0.2123135   1.1886889 ] 1.0
# 11 [ 0.00523264 -0.15205304  0.03059083  0.2527525 ] 1.0
# 12 [ 0.00219158  0.04261905  0.03564588 -0.0301267 ] 1.0
# 13 [ 0.00304396  0.23721217  0.03504335 -0.31135327] 1.0
# 14 [ 0.00778821  0.04160893  0.02881628 -0.00782794] 1.0
# 15 [ 0.00862039  0.23630603  0.02865972 -0.29128152] 1.0
# 16 [0.01334651 0.04078739 0.02283409 0.0103008 ] 1.0
# 17 [ 0.01416225  0.23557456  0.02304011 -0.27509114] 1.0
# 18 [ 0.01887375  0.43036032  0.01753829 -0.5604191 ] 1.0
# 19 [ 0.02748095  0.23499668  0.00632991 -0.26226264] 1.0
